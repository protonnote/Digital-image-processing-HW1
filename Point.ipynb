# %%
import numpy as np
import matplotlib.pyplot as plt
import cv2

# %%
img1 = cv2.imread('D:/Project/DIP/2/Cameraman.pgm',0)
img2 = cv2.imread('D:/Project/DIP/2/SEM256_256.pgm',0)

# %%
equ = cv2.equalizeHist(img1)
res = np.hstack((img1,equ))
cv2.imwrite('./res.png',res)

# %%
h2 = np.array(img1).flatten()
ppllt = plt.hist(h2,256)
plt.xlim([-3,260])
plt.title("Original")
# Out:
# Text(0.5, 1.0, 'Original')

# %%
h1 = np.array(equ).flatten()
pplt = plt.hist(h1,256)
plt.xlim([-3,260])
plt.title("After")
# Out:
# Text(0.5, 1.0, 'Histograms Equalization')

# %%
equ2 = cv2.equalizeHist(img2)
res2 = np.hstack((img2,equ2))
cv2.imwrite('res2.png',res2)
# Out:
# True

# %%
h22 = np.array(img2).flatten()
ppllt = plt.hist(h22,256)
plt.xlim([0,260])
plt.title("Original")
# Out:
# Text(0.5, 1.0, 'Original')

# %%
h21 = np.array(equ2).flatten()
ppllt = plt.hist(h21,256)
plt.xlim([-5,260])
plt.title("Histograms Equalization")
# Out:
# Text(0.5, 1.0, 'Histograms Equalization')
